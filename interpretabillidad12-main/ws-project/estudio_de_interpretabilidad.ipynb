# %% [markdown]
# Estudio de interpretabilidad de modelos con Redes Neuronales y Random Forest

# %%
import estudio_de_interpretabilidad as ei
import generador_de_modelos as gm
import numpy as np

# %% [markdown]
# Puede generar modelos de los dos datasets utilizando gm.occupation_models() o gm.drybean_models()
# Esto generará un modelo de Redes Neuronales y otro de Random Forest.
# Para generar las explicaciones a estos modelos utilizamos ei.generar_explicaciones()

# %% [markdown]
# Dataset de Occupancy_Estimation

# %%
rn_occupation_model, rf_occupation_model, occupation_muestras_prueba, occupation_clases_prueba, occupation_min_vals, occupation_max_vals = gm.occupation_models()
# Out:
# ==============RED NEURONAL==================
# Epoch 1/20
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2785 - accuracy: 0.6781
# Epoch 2/20
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0523 - accuracy: 0.8141
# Epoch 3/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9157 - accuracy: 0.8139
# Epoch 4/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.8274 - accuracy: 0.8139
# Epoch 5/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.7653 - accuracy: 0.8139
# Epoch 6/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.7177 - accuracy: 0.8139
# Epoch 7/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6787 - accuracy: 0.8139
# Epoch 8/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6450 - accuracy: 0.8139
# Epoch 9/20
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6149 - accuracy: 0.8139
# Epoch 10/20
# ...

# %% [markdown]
# Occupancy Estimation: Generación de explicaciones con el algoritmo LIME

# %%
N = 100 # Número de muestras perturbadas a generar
k = 10 # Número de características a perturbar por cada iteración
indice_prueba = 0 # Índice de la muestra de prueba a explicar

occupation_x1 = occupation_muestras_prueba.iloc[indice_prueba].values
print("Muestra: ", occupation_x1)
occupation_explicacion_rn, occupation_explicacion_rf= ei.generar_explicaciones(
    rn_occupation_model, rf_occupation_model, occupation_muestras_prueba, occupation_min_vals, occupation_max_vals, N, k, indice_prueba
)
# Out:
# Muestra:  [0.25694444 0.13176471 0.32       ... 0.41213494 0.         0.        ]
# 4/4 [==============================] - 0s 1ms/step

# %%
print("Explicacion RN")
print("Matriz de coeficientes:")
print(occupation_explicacion_rn[0])
print("Vector de interceptores:")
print(occupation_explicacion_rn[1])
# Out:
# Explicacion RN
# Matriz de coeficientes:
# [[-0.04896674 -0.02092802 -0.01975941 -0.05309762  0.0714136   0.10148332
#    0.02510443 -0.00556081 -0.02881149  0.04642263 -0.04416704 -0.04402365
#    0.06616138 -0.06600184  0.03235108 -0.01161985]
#  [ 0.01312048 -0.00037831  0.00585246  0.00468044 -0.01889368 -0.01048038
#   -0.00402755 -0.00031608 -0.00140207 -0.00528185  0.00206794  0.01033678
#   -0.01238747  0.00988876 -0.00585605  0.01307659]
#  [ 0.02316542  0.00941427  0.01529903  0.03097803 -0.04203223 -0.05082995
#   -0.0142998  -0.00338383  0.00823275 -0.0187394   0.02150281  0.02139493
#   -0.02936351  0.03354812 -0.00919506  0.00430843]
#  [ 0.01268084  0.01189208 -0.00139208  0.01743916 -0.01048769 -0.04017299
#   -0.00677708  0.00926072  0.02198079 -0.02240139  0.02059628  0.01229194
#   -0.0244104   0.02256496 -0.01729999 -0.00576517]]
# Vector de interceptores:
# [0.61552766 0.08175017 0.17021497 0.1325072 ]

# %%
print("Explicacion Random Forest")
print("Matriz de coeficientes:")
print(occupation_explicacion_rf[0])
print("Vector de interceptores:")
print(occupation_explicacion_rf[1])
# Out:
# Explicacion Random Forest
# Matriz de coeficientes:
# [[-0.06920646  0.05295887 -0.02182753 -0.0052622   0.18619476 -0.02891473
#   -0.08157323  0.01661689  0.02662654  0.07186382 -0.01620235  0.00061131
#   -0.06207603 -0.00049878 -0.06188126 -0.00742961]
#  [ 0.0139773   0.01801734  0.00073499 -0.04172192 -0.21414544  0.10958026
#    0.0749498  -0.03594134 -0.06062996 -0.05710027  0.09407036  0.03432439
#   -0.05458021  0.0589051   0.04191758  0.01764203]
#  [-0.03192759 -0.0229522   0.04271328  0.01645508 -0.11153887  0.03183214
#    0.00210286 -0.0412724  -0.02553089 -0.01146753  0.05492654 -0.00812473
#    0.00100685  0.01074509  0.02856482  0.06446757]
#  [ 0.08715675 -0.04802401 -0.02162073  0.03052904  0.13948955 -0.11249767
#    0.00452057  0.06059686  0.05953431 -0.00329603 -0.13279455 -0.02681097
#    0.1156494  -0.06915141 -0.00860114 -0.07467998]]
# Vector de interceptores:
# [0.26152365 0.16964134 0.09140246 0.47743254]

# %% [markdown]
# Dataset Dry Bean

# %%
rn_drybean_model, rf_drybean_model, drybean_muestras_prueba, drybean_clases_prueba, drybean_min_vals, drybean_max_vals= gm.drybean_models()
# Out:
# ==============RED NEURONAL==================
# Epoch 1/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.9516 - accuracy: 0.3006
# Epoch 2/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.8569 - accuracy: 0.2634
# Epoch 3/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.8061 - accuracy: 0.2633
# Epoch 4/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.7690 - accuracy: 0.2635
# Epoch 5/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.7394 - accuracy: 0.2648
# Epoch 6/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.7147 - accuracy: 0.2720
# Epoch 7/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.6923 - accuracy: 0.2834
# Epoch 8/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.6718 - accuracy: 0.3077
# Epoch 9/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.6520 - accuracy: 0.3216
# Epoch 10/20
# ...

# %% [markdown]
# Dry Bean: Generación de explicaciones con el algoritmo LIME

# %%
N = 100 # Número de muestras perturbadas a generar
k = 10 # Número de características a perturbar por cada iteración
indice_prueba = 0 # Índice de la muestra de prueba a explicar

drybean_x1 = drybean_muestras_prueba.iloc[indice_prueba].values
drybean_explicacion_rn, drybean_explicacion_rf= ei.generar_explicaciones(
    rn_drybean_model, rf_drybean_model, drybean_muestras_prueba, drybean_min_vals, drybean_max_vals, N, k, indice_prueba
)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
print("Explicacion Redes Neuronales")
print("Matriz de coeficientes:")
print(drybean_explicacion_rn[0])
print("Vector de interceptores:")
print(drybean_explicacion_rn[1])
# Out:
# Explicacion Redes Neuronales
# Matriz de coeficientes:
# [[ 0.01367729 -0.01692166 -0.00479234 -0.00606497  0.01125495  0.00226965
#    0.00032359  0.00064157  0.00031762  0.00674189 -0.01122717  0.00409266
#    0.0003564   0.00804136  0.00210887 -0.0108197 ]
#  [ 0.00605128 -0.0037141   0.00592078 -0.00131417  0.00729783  0.00206941
#   -0.00617236 -0.000998    0.00159265 -0.00342029  0.00043356  0.00698352
#    0.00169255 -0.00460716 -0.0027834  -0.0090321 ]
#  [ 0.00128733 -0.00135729  0.0004955  -0.01357459 -0.00311968  0.00868516
#    0.00076248 -0.00629088  0.00376939 -0.00223406 -0.00432543 -0.00057377
#    0.01016262  0.00446873  0.00381837 -0.00197389]
#  [-0.01911732  0.00527293 -0.02049259  0.019597   -0.00494763 -0.01636136
#    0.0174622   0.03135151  0.0022843   0.00311394 -0.0008798  -0.00771303
#   -0.01134379 -0.00180237 -0.00563341  0.00920942]
#  [ 0.01167329  0.0077808   0.01302816 -0.00936442 -0.01787324  0.01784096
# ...

# %%
np.set_printoptions(threshold=1000)

print("Explicacion Random Forest")
print("Matriz de coeficientes:")
print(drybean_explicacion_rf[0])
print("Vector de interceptores:")
print(drybean_explicacion_rf[1])
# Out:
# Explicacion Random Forest
# Matriz de coeficientes:
# [[ 0.01757712 -0.09846365 -0.08057855  0.02019732  0.00531447  0.01695316
#    0.00499387  0.0063739   0.00496428 -0.01448035 -0.00680727  0.05689399
#    0.00894996 -0.00684662  0.024315    0.04064338]
#  [-0.0240015  -0.0871942  -0.05865952 -0.00130877 -0.02705106  0.04949185
#   -0.00411027  0.033907    0.03959619  0.01040425  0.02798212  0.0544121
#   -0.0564308  -0.02852818  0.05014708  0.02134371]
#  [ 0.01487455 -0.05431543 -0.05317773 -0.00136383 -0.00415589  0.0133473
#    0.00494423  0.02575567  0.00033902 -0.01051907  0.03791294 -0.00532436
#    0.00829967 -0.01905816  0.00099725  0.04144383]
#  [-0.01325399  0.1179079   0.13828228 -0.01040483  0.02548807 -0.03042995
#   -0.0225302  -0.00868056  0.00345694 -0.00724894 -0.00720873 -0.04309213
#   -0.0913343   0.01517005 -0.03805822 -0.02806339]
#  [ 0.03348334 -0.01409817 -0.04135277  0.0101022   0.03210302 -0.01859642
# ...

# %% [markdown]
# Evaluación de las explicaciones con las siguientes métricas:
# - Identidad
# - Separabilidad
# - Estabilidad
# - Selectividad
#
# Están implementadas en el fichero metrics.py
# Y se ejecutan, junto con las funciones anteriores mediante la función ei.estudio_metricas()

# %% [markdown]
# Occupancy Estimation: Generación de modelos, Explicaciones y evaluación con Métricas

# %%
np.set_printoptions(threshold=10)

dataset = 1 # 1 para occupation, 2 para drybean
muestra1 = 0 # indice de la muestra de prueba 1
muestra2 = 1 # indice de la muestra de prueba 2 
metricas_rn, metricas_rf = ei.estudio_metricas(dataset, muestra1, muestra2)
# Out:
# Está generando modelos del dataset Occupation
# ==============RED NEURONAL==================
# Epoch 1/20
# 31/31 [==============================] - 0s 1ms/step - loss: 1.2256 - accuracy: 0.7936
# Epoch 2/20
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0173 - accuracy: 0.8215
# Epoch 3/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.8833 - accuracy: 0.8139
# Epoch 4/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.7953 - accuracy: 0.8139
# Epoch 5/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.7323 - accuracy: 0.8139
# Epoch 6/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6827 - accuracy: 0.8139
# Epoch 7/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6409 - accuracy: 0.8140
# Epoch 8/20
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6044 - accuracy: 0.8150
# Epoch 9/20
# ...

# %% [markdown]
# Dry Bean: Generación de modelos, Explicaciones y evaluación con Métricas

# %%
dataset = 2 # 1 para occupation, 2 para drybean
muestra1 = 0 # indice de la muestra de prueba 1
muestra2 = 1 # indice de la muestra de prueba 2 
metricas_rn, metricas_rf = ei.estudio_metricas(dataset, muestra1, muestra2)
# Out:
# Está generando modelos del dataset Dry Bean
# ==============RED NEURONAL==================
# Epoch 1/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.9203 - accuracy: 0.1739
# Epoch 2/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.8533 - accuracy: 0.2658
# Epoch 3/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.8160 - accuracy: 0.2632
# Epoch 4/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.7873 - accuracy: 0.2632
# Epoch 5/20
# 37/37 [==============================] - 0s 2ms/step - loss: 1.7626 - accuracy: 0.2632
# Epoch 6/20
# 37/37 [==============================] - 0s 2ms/step - loss: 1.7433 - accuracy: 0.2632
# Epoch 7/20
# 37/37 [==============================] - 0s 1ms/step - loss: 1.7262 - accuracy: 0.2632
# Epoch 8/20
# 37/37 [==============================] - 0s 2ms/step - loss: 1.7096 - accuracy: 0.2632
# Epoch 9/20
# ...
